# %% [markdown]
# # nbis ChIP-seq
#
# from https://nbis-workshop-epigenomics.readthedocs.io/en/latest/content/tutorials/chipseqBroadPeaks/lab-broadpeaks.html
#
# This is meant to be run in sessions launched from [here](https://github.com/OliviaRN/CHIPseq_Upstate).
# Or [click this link directly to launch](https://mybinder.org/v2/gh/OliviaRN/CHIPseq_Upstate/HEAD) to launch a session.
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/OliviaRN/CHIPseq_Upstate/HEAD)

# %% [markdown]
# Get the data

# %%
# !curl -O -L https://www.encodeproject.org/files/ENCFF263XBT/@@download/ENCFF263XBT.bam

# %%
# !curl -O -L https://www.encodeproject.org/files/ENCFF992ZBS/@@download/ENCFF992ZBS.bam

# %% [markdown]
# -----------
#
#
# Call peaks

# %%
# !macs3 callpeak --broad \
-t ENCFF263XBT.bam \
-c ENCFF992ZBS.bam \
-f BAMPE  -g 04.9e8 --broad-cutoff 0.1 -n first
